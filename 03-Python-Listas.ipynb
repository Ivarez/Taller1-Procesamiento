# %% [markdown]
# # Procesamiento de Datos a Gran Escala
# ## Cuaderno 03: Listas en Python
# **Autor:** Iván Alvarez
#
# **Descripción Personal:**
# En este tercer cuaderno se introducen las listas en Python. A diferencia de las tuplas, las listas son estructuras dinámicas y mutables, lo que permite agregar, eliminar o modificar elementos en tiempo de ejecución. Son fundamentales para agrupar y transformar secuencias de datos.

# %% [markdown]
# ### Solución del Examen sobre Listas en Python
# A continuación, se presenta la resolución de los ejercicios planteados en el taller, documentando la ejecución de cada instrucción.

# %%
# Pregunta 1: Crear una lista con diferentes tipos de datos
# Se agrupan enteros, cadenas, listas anidadas y booleanos.
a_list = [1, 'hello', [1, 2, 3], True]
print("Lista creada:", a_list)

# %%
# Pregunta 2: Encontrar el valor en el índice 1
# Se accede directamente a la segunda posición de la lista.
valor_indice_1 = a_list[1]
print("Valor en índice 1:", valor_indice_1)

# %%
# Pregunta 3: Obtener los elementos almacenados en los índices 1, 2 y 3
# Se utiliza la técnica de slicing [1:4] para extraer la sublista requerida.
sublista = a_list[1:4]
print("Elementos del índice 1 al 3:", sublista)

# %%
# Pregunta 4: Concatenar las listas A y B
A = [1, 'a']
B = [2, 1, 'd']
# Se emplea el operador de suma para unir ambas secuencias en una sola lista.
lista_concatenada = A + B
print("Listas concatenadas:", lista_concatenada)

# %% [markdown]
# ### Conclusiones
# La mutabilidad de las listas me parece una de sus características más potentes. A través de este taller, comprendo claramente cómo el contenido puede ser modificado y cómo operaciones como el slicing permiten extraer sublistas útiles. Me resulta particularmente interesante el concepto de copiado y clonación; entender que clonar una lista con `[:]` crea una nueva referencia en memoria es vital para evitar alterar accidentalmente los datos originales durante el procesamiento.
